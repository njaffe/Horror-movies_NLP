# %%
import os
from urllib.parse import quote

from bs4 import BeautifulSoup
import requests

import pandas as pd
import numpy as np

import pickle

# %% [markdown]
# # 1. Obtained functions from github

# %% [markdown]
# Functions obtained from:
# https://github.com/j2kun/imsdb_download_all_scripts/blob/main/download_all_scripts.py

# %%
BASE_URL = 'http://www.imsdb.com'
SCRIPTS_DIR = 'scripts'


def clean_script(text):
    text = text.replace('Back to IMSDb', '')
    text = text.replace('''<b><!--
</b>if (window!= top)
top.location.href=location.href
<b>// -->
</b>
''', '')
    text = text.replace('''          Scanned by http://freemoviescripts.com
          Formatting by http://simplyscripts.home.att.net
''', '')
    return text.replace(r'\r', '')


def get_script(relative_link):
    tail = relative_link.split('/')[-1]
    print('fetching %s' % tail)
    script_front_url = BASE_URL + quote(relative_link)
    front_page_response = requests.get(script_front_url)
    front_soup = BeautifulSoup(front_page_response.text, "html.parser")

    try:
        script_link = front_soup.find_all('p', align="center")[0].a['href']
    except IndexError:
        print('%s has no script :(' % tail)
        return None, None

    if script_link.endswith('.html'):
        title = script_link.split('/')[-1].split(' Script')[0]
        script_url = BASE_URL + script_link
        script_soup = BeautifulSoup(requests.get(script_url).text, "html.parser")
        script_text = script_soup.find_all('td', {'class': "scrtext"})[0].get_text()
#         script_text = clean_script(script_text)
        return title, script_text
    else:
        print('%s is a pdf :(' % tail)
        return None, None


# if __name__ == "__main__":
#     response = requests.get('http://www.imsdb.com/all%20scripts/')
#     html = response.text

#     soup = BeautifulSoup(html, "html.parser")
#     paragraphs = soup.find_all('p')

#     for p in paragraphs:
#         relative_link = p.a['href']
#         title, script = get_script(relative_link)
#         if not script:
#             continue

#         with open(os.path.join(SCRIPTS_DIR, title.strip('.html') + '.txt'), 'w') as outfile:
#             outfile.write(script)

# %% [markdown]
# # 2. Trying them step by step for comprehension

# %%
import os
from urllib.parse import quote

from bs4 import BeautifulSoup
import requests

import pandas as pd
import numpy as np

# %% [markdown]
# ## Starting from home page

# %%
SCRIPTS_DIR = 'scripts'

BASE_URL = 'http://www.imsdb.com'

horror_home_url = 'https://www.imsdb.com/genre/Horror'

response = requests.get(horror_home_url)
html = response.text

soup = BeautifulSoup(html, "html.parser")
paragraphs = soup.find_all('p')

# %%
relative_link = paragraphs[0].a['href']
print(relative_link)
# Out:
# /Movie Scripts/28 Days Later Script.html

# %% [markdown]
# ## Movie page

# %%
# get movie page url
script_front_url = BASE_URL + quote(relative_link)
print(script_front_url)

# get to movie page
front_page_response = requests.get(script_front_url)
front_soup = BeautifulSoup(front_page_response.text, "html.parser")

front_soup
# Out:
# http://www.imsdb.com/Movie%20Scripts/28%20Days%20Later%20Script.html
# <html>
# <head><title>28 Days Later Script at IMSDb.</title>
# <meta content="28 Days Later script at the Internet Movie Script Database." name="description"/>
# <meta content="28 Days Later script, 28 Days Later movie script, 28 Days Later film script" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta content="true" name="HandheldFriendly"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="EN" http-equiv="Content-Language"/>
# <meta content="Document" name="objecttype"/>
# <meta content="INDEX, FOLLOW" name="ROBOTS"/>
# <meta content="Movie scripts, Film scripts" name="Subject"/>
# <meta content="General" name="rating"/>
# <meta content="Global" name="distribution"/>
# <meta content="2 days" name="revisit-after"/>
# <link href="/style.css" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ## Script link

# %%
script_link = front_soup.find_all('p', align="center")[0].a['href']
date = front_soup.find_all('td')[5]
# ['Movie Release Date'].text
print(date)
# Out:
# <td valign="top" width="180">
# <table border="0" cellpadding="2" cellspacing="0" width="100%">
# <tr>
# <td class="heading" colspan="2">Search IMSDb</td>
# </tr>
# <tr>
# <form action="/search.php" method="post">
# <td bgcolor="#FFFFFF" width="180"><div align="center">
# <input maxlength="255" name="search_query" size="15" type="text"/>
# <input name="submit" type="submit" value="Go!"/>
# </div></td>
# </form>
# </tr>
# </table>
# <br/>
# <table class="body" width="100%">
# <tr>
# <td class="heading" colspan="9">Alphabetical</td>
# <tr align="center">
# <td><a href="/alphabetical/0">#</a></td>
# <td><a href="/alphabetical/A">A</a></td>
# <td><a href="/alphabetical/B">B</a></td>
# <td><a href="/alphabetical/C">C</a></td>
# <td><a href="/alphabetical/D">D</a></td>
# <td><a href="/alphabetical/E">E</a></td>
# <td><a href="/alphabetical/F">F</a></td>
# <td><a href="/alphabetical/G">G</a></td>
# <td><a href="/alphabetical/H">H</a></td>
# </tr>
# <tr align="center">
# ...

# %%
if script_link.endswith('.html'):
    title = script_link.split('/')[-1].split(' Script')[0]
    script_url = home_url + script_link
    script_soup = BeautifulSoup(requests.get(script_url).text, "html.parser")
    script_text = script_soup.find_all('td', {'class': "scrtext"})[0].get_text()
#     script_text = clean_script(script_text)
#     print(title, script_text)
    print(title)
else:
    print('%s is a pdf :(' % tail)

# %% [markdown]
# # 3. Applying above functions together to scrape

# %%
home_url = 'http://www.imsdb.com'

horror_home_url = 'https://www.imsdb.com/genre/Horror'

response = requests.get(horror_home_url)
html = response.text

soup = BeautifulSoup(html, "html.parser")
paragraphs = soup.find_all('p')
for p in paragraphs:
    relative_link = p.a['href']
    title, script = get_script(relative_link)
#     print(title)
    if not script:
        continue

    with open(os.path.join(SCRIPTS_DIR, title.strip('.html') + '.txt'), 'w') as outfile:
        outfile.write(script)
# Out:
# fetching 28 Days Later Script.html
# fetching A Quiet Place Script.html
# fetching Addams Family, The Script.html
# fetching After.Life Script.html
# fetching Alien Script.html
# fetching Alien 3 Script.html
# fetching Alien vs. Predator Script.html
# fetching Alien: Resurrection Script.html
# fetching Aliens Script.html
# fetching Alone in the Dark Script.html
# fetching American Psycho Script.html
# fetching American Werewolf in London Script.html
# fetching Amityville Asylum, The Script.html
# fetching April Fool's Day Script.html
# fetching Army of Darkness Script.html
# fetching Bad Dreams Script.html
# fetching Birds, The Script.html
# fetching Blade Script.html
# fetching Blade II Script.html
# fetching Blade: Trinity Script.html
# fetching Bones Script.html
# fetching Buffy the Vampire Slayer Script.html
# fetching Carrie Script.html
# fetching Case 39 Script.html
# fetching Cell, The Script.html
# fetching Chasing Sleep Script.html
# fetching Cherry Falls Script.html
# ...

# %% [markdown]
# Result: text file for each script!

# %% [markdown]
# # 4. Finally, read text files into CSV with movie name

# %%
full_scripts_dir_path = '/Users/Noah/Github_repos/Project_4/scripts'

names = []
texts = []
for file in os.listdir(full_scripts_dir_path):

    print('Reading in {}...'.format(file))
    
    with open(full_scripts_dir_path + '/' + file, 'r') as f:
        names.append(file[:-4])
        texts.append(f.read())
# Out:
# Reading in Hellraiser-Hellseeker.txt...
# Reading in Screa.txt...
# Reading in Lord-of-Illusions.txt...
# Reading in Dawn-of-the-Dead.txt...
# Reading in Blade-II.txt...
# Reading in Gremlins-2.txt...
# Reading in Mulholland-Drive.txt...
# Reading in What-Lies-Benea.txt...
# Reading in House-of-1000-Corpses.txt...
# Reading in Mute-Witness.txt...
# Reading in Land-of-the-Dead.txt...
# Reading in Hanniba.txt...
# Reading in Slither.txt...
# Reading in Red-Riding-Hood.txt...
# Reading in Pet-Sematary-II.txt...
# Reading in Mimic.txt...
# Reading in Little-Nicky.txt...
# Reading in Gothika.txt...
# Reading in Twin-Peaks.txt...
# Reading in Jaws.txt...
# Reading in Deep-Rising.txt...
# Reading in Heavenly-Creatures.txt...
# Reading in Peeping-To.txt...
# Reading in Perfect-Creature.txt...
# Reading in Aliens.txt...
# Reading in Wind-Chi.txt...
# Reading in Friday-the-13.txt...
# Reading in Eight-Legged-Freaks.txt...
# Reading in Halloween.txt...
# Reading in Nightbreed.txt...
# ...

# %%
df = pd.DataFrame(list(zip(names, texts)), columns = ['names', 'texts'])

# %%
df.head()
# Out:
#                    names                                              texts
# 0  Hellraiser-Hellseeker  \n\n\n                HELLRAISER: HELLSEEKER\n...
# 1                  Screa  \n                                \n          ...
# 2      Lord-of-Illusions  \n\n\n\n"Lord of Illusions" -- by Clive Barker...
# 3       Dawn-of-the-Dead  \nDAWN OF\nTHE DEAD\n(The working draft 1977)\...
# 4               Blade-II                 \n"BLADE II" -- by David Goyer\n\n

# %% [markdown]
# # Pickling file

# %%
filename = 'movie_scripts_df'
outfile = open(filename,'wb')
pickle.dump(df,outfile)
outfile.close()
